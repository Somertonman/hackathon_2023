# %%
import pandas as pd
import re

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.options.mode.chained_assignment = None

# %%
# !pip install pymorphy2
import pymorphy2

# %%
# !pip install transformers sacremoses
from transformers import pipeline

qa_pipeline = pipeline("question-answering", "timpal0l/mdeberta-v3-base-squad2")

# %%
# !wget -O dataset https://www.dropbox.com/sh/d5h5f3yrql8x392/AACQ2WYa5qYCqjC8QuVZ5TJ4a?dl=1

# %%
# !unzip dataset

# %%
# !tar -xvf  '/content/task_3/full_dataset/json.tar' -C '/content/task_3'

# %%
def im_pad(text):
  words = text.split()
  nominative_words = []
  for word in words:
    parsed_word = morph.parse(word)[0]
    nominative_word = parsed_word.normal_form
    nominative_words.append(nominative_word)
  nominative_sentence = " ".join(nominative_words)
  return nominative_sentence

# %%
def parse_file(file_name):
  df = pd.read_json(file_name).reset_index()

  id = re.search(r'\d*', file_name).group()
  df['id'] = id

  df = df.query('index not in ("Global_deadline", "Global_supervisor")')
  df['task_text'] = df.apply(lambda x: x['Tasks']['task_text'], axis = 1)
  df['task_responsibles_people'] = df.apply(lambda x: x['Tasks']['task_responsibles_people'], axis = 1)
  df['task_responsibles_groups'] = df.apply(lambda x: x['Tasks']['task_responsibles_groups'], axis = 1)

  question = "Какая должность?"
  df['position'] = df.apply(lambda x: im_pad(qa_pipeline(question, x['task_responsibles_people'])['answer']), axis = 1)

  question = "Какое имя?"
  df['name'] = df.apply(lambda x: im_pad(qa_pipeline(question, x['task_responsibles_people'])['answer']), axis = 1)

  df = df[['id', 'index', 'task_text', 'task_responsibles_groups', 'position', 'name']]
  return df.rename(columns={'index':'task_num', 'task_responsibles_groups':'dept'})

# %%
df = parse_file('/content/task_3/json/0.json')

for i in range (1, 10):
  file_name = f"/content/task_3/json/{i}.json"
  df_one = parse_file(file_name)
  df = pd.concat([df, df_one])

# %%
df
# Out:
#   id task_num                                          task_text  \
# 2       Task1        Закупить книги. Срок завершения: 19 апр 15.
# 2       Task1  Провести анализ поставщиков для замены вышедше...
# 3       Task2  Выполнить ремонт кабеля сети передачи данных м...
# 4       Task3  Создать и настроить виртуальную машину в соотв...
# 2       Task1  Провести рефакторинг программного обеспечения ...
# 3       Task2  Провести рефакторинг программного обеспечения ...
# 4       Task3  Провести анализ накопленного технического долг...
# 5       Task4  Организовать регулярное проведение статус-мити...
# 6       Task5  Интегрировать в систему модуль мониторинга для...
# 7       Task6  Интегрировать в систему модуль мониторинга для...
# 2       Task1  Оплатить командировочные расходы.\nОпределить ...
# 3       Task2  Провести аудит персональных данных в информаци...
# 4       Task3  Перечислить необходимые средства на закупку об...
# 5       Task4  Произвести расчет и выплату премии.\nОпределит...
# 6       Task5  Перечислить необходимые средства на закупку об...
# 2       Task1  Согласовать смету на выполнение работ компание...
# 3       Task2  Выделить средства на проведение обучения.\nУст...
# 2       Task1  Внести изменения в техническую документацию пр...
# 3       Task2  Оказать содействие в подготовке пользовательск...
# 4       Task3  Согласовать проект системы с разработчиками.\n...
# 5       Task4  Подготовить спецификацию проекта для формирова...
# 6       Task5  Подготовить спецификацию проекта для формирова...
# 7       Task6  Сохранить проектную документацию в архиве.\nЗа...
# 8       Task7  Провести обучение сотрудником работе с програм...
# 9       Task8  Подготовить спецификацию необходимого аппаратн...
# 2       Task1  Выполнить сверку расчетов с компаниями-пордядч...
# 3       Task2  Провести анализ выплат сотрудникам за работу в...
# 2       Task1  Провести анализ неисправности работы API и обе...
# 3       Task2  Провести анализ неисправности работы API и обе...
# 2       Task1  Добавить дополнительных механизм авторизации п...
# 2       Task1  Организовать VPN соединение для взаимодействия...
# 3       Task2  Установить дополнительное аппаратное обеспечен...
#
#                                   dept  \
# 2  Административно-хозяйственный отдел
# 2                            Служба ИТ
# 3                            Служба ИТ
# 4                            Служба ИТ
# 2              Отдел разработки систем
# 3              Отдел разработки систем
# 4              Отдел разработки систем
# 5              Отдел разработки систем
# 6              Отдел разработки систем
# 7              Отдел разработки систем
# 2                          Бухгалтерия
# 3                          Бухгалтерия
# 4                          Бухгалтерия
# 5                          Бухгалтерия
# 6                          Бухгалтерия
# 2                          Бухгалтерия
# 3                          Бухгалтерия
# 2                 Отдел проектирования
# 3                 Отдел проектирования
# 4                 Отдел проектирования
# 5                 Отдел проектирования
# 6                 Отдел проектирования
# 7                 Отдел проектирования
# 8                 Отдел проектирования
# 9                 Отдел проектирования
# 2                          Бухгалтерия
# 3                          Бухгалтерия
# 2              Отдел разработки систем
# 3              Отдел разработки систем
# 2              Отдел разработки систем
# 2                            Служба ИТ
# 3                            Служба ИТ
#
#                                             position                 name
# 2  специалист первый категория административно-хо...         кравцов и.е.
# 2              специалист третий категория служба ит    ким юрий иванович
# 3                            системный администратор       сергеев андрей
# 4                        специалист третий категория    ким юрий иванович
# 2               контроль над исполнение распоряжение        абаимов симон
# 3                          тимлида проектный команда       абаимов симона
# 4                                        программист        абашкин орест
# 5                               технический писатель        абалкин зураб
# 6                        специалист третий категория         андреев с.е.
# 7  специалист третий категория отдел разработка с...         андреев с.е.
# 2                                  оставлять за себя                 себя
# 3             специалист треть категория бухгалтерия     александров а.с.
# 4                                  оставлять за себя                 себя
# 5                       второй категория бухгалтерия         смирнов о.а.
# 6            специалист второй категория бухгалтерия         смирнов о.а.
# 2                                  оставлять за себя                 себя
# 3            специалист второй категория бухгалтерия         смирнов о.а.
# 2                  руководитель отдел проектирование                шихов
# 3                                  оставлять за себя                 себя
# 4   специалист первый категория отдел проектирование         семёнов и.а.
# 5   специалист первый категория отдел проектирование         семёнов и.а.
# 6                  руководитель отдел проектирование           шихов р.п.
# 7                  руководитель отдел проектирование                шихов
# 8   специалист первый категория отдел проектирование         семёнов и.а.
# 9              первый категория отдел проектирование         семёнов и.а.
# 2            специалист второй категория бухгалтерия         смирнов о.а.
# 3                                  главное бухгалтер         семёнов м.с.
# 2  специалист третий категория отдел разработка с...         андреев с.е.
# 3                                        программист        абашкин орест
# 2                        специалист второй категория           попов а.а.
# 2                          администратор база данные      абакуловый пётр
# 3                            системный администратор  абалаково севастьян
